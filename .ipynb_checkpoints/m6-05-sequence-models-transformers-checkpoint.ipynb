# %%
pip install numpy pandas matplotlib torch torchtext scikit-learn
# Out:
# ...
#   Using cached tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# ...
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.5/2.0 MB 670.4 kB/s eta 0:00:03
#    ---------- ----------------------------- 0.5/2.0 MB 670.4 kB/s eta 0:00:03
#    ---------- ----------------------------- 0.5/2.0 MB 670.4 kB/s eta 0:00:03
#    ---------- ----------------------------- 0.5/2.0 MB 670.4 kB/s eta 0:00:03
#    ---------- ----------------------------- 0.5/2.0 MB 670.4 kB/s eta 0:00:03
#    ---------- ----------------------------- 0.5/2.0 MB 670.4 kB/s eta 0:00:03
# ...

# %%
# !pip install datasets
# Out:
# ...
#   Using cached tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# ...
#    ---------------------------------------- 0.0/529.0 kB ? eta -:--:--
#    ------------------- -------------------- 262.1/529.0 kB ? eta -:--:--
#    ---------------------------------------- 529.0/529.0 kB 2.9 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/663.6 kB ? eta -:--:--
#    ------------------------------- -------- 524.3/663.6 kB 3.3 MB/s eta 0:00:01
#    ---------------------------------------- 663.6/663.6 kB 2.3 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/27.4 MB ? eta -:--:--
#     --------------------------------------- 0.5/27.4 MB 3.4 MB/s eta 0:00:08
#    - -------------------------------------- 1.3/27.4 MB 3.2 MB/s eta 0:00:09
#    --- ------------------------------------ 2.1/27.4 MB 3.4 MB/s eta 0:00:08
#    ---- ----------------------------------- 2.9/27.4 MB 3.5 MB/s eta 0:00:08
#    ---- ----------------------------------- 3.4/27.4 MB 3.4 MB/s eta 0:00:08
# ...

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time

device = "cuda" if torch.cuda.is_available() else "cpu"
torch.manual_seed(42)

# %%
from datasets import load_dataset

dataset = load_dataset("imdb")

texts  = list(dataset["train"]["text"]) + list(dataset["test"]["text"])
labels = list(dataset["train"]["label"]) + list(dataset["test"]["label"])

df = pd.DataFrame({"text": texts, "label": labels})
df = df.sample(5000, random_state=42).reset_index(drop=True)

print(f"Dataset size: {len(df)}")
print(df["label"].value_counts())
# Out:
# ...
# Dataset size: 5000
# label
# 1    2504
# 0    2496
# Name: count, dtype: int64

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
from collections import Counter
from datasets import load_dataset

device = "cuda" if torch.cuda.is_available() else "cpu"
torch.manual_seed(42)

# ── 1. Dataset ────────────────────────────────────────────────
dataset = load_dataset("imdb")
texts  = list(dataset["train"]["text"]) + list(dataset["test"]["text"])
labels = list(dataset["train"]["label"]) + list(dataset["test"]["label"])
df = pd.DataFrame({"text": texts, "label": labels})
df = df.sample(5000, random_state=42).reset_index(drop=True)

# ── 2. Tokenize ───────────────────────────────────────────────
def tokenize(text):
    return text.lower().split()
df["tokens"] = df["text"].apply(tokenize)

# ── 3. Vocabulary ─────────────────────────────────────────────
train_size = int(0.8 * len(df))
train_df = df[:train_size]

counter = Counter()
for tokens in train_df["tokens"]:
    counter.update(tokens)

vocab = {"<pad>": 0, "<unk>": 1}
for word, _ in counter.most_common(10000 - 2):
    vocab[word] = len(vocab)

print(f"Vocabulary size: {len(vocab)}")

# ── 4. Encode ─────────────────────────────────────────────────
MAX_LEN = 200

def encode(tokens, max_len=MAX_LEN):
    ids = [vocab.get(t, 1) for t in tokens]
    ids = ids[:max_len]
    ids += [0] * (max_len - len(ids))
    return ids

df["encoded"] = df["tokens"].apply(encode)

# ── 5. DataLoader ─────────────────────────────────────────────
class IMDBDataset(Dataset):
    def __init__(self, dataframe):
        self.X = torch.tensor(dataframe["encoded"].tolist(), dtype=torch.long)
        self.y = torch.tensor(dataframe["label"].tolist(), dtype=torch.long)
    def __len__(self):
        return len(self.X)
    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

train_dataset = IMDBDataset(df[:train_size])
val_dataset   = IMDBDataset(df[train_size:])
train_loader  = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader    = DataLoader(val_dataset,   batch_size=32)

print(f"Train: {len(train_dataset)} | Val: {len(val_dataset)}")

# ── 6. Sample ─────────────────────────────────────────────────
print(f"\nReview : {df['text'].iloc[0][:80]}...")
print(f"Tokens : {df['tokens'].iloc[0][:10]}")
print(f"Encoded: {df['encoded'].iloc[0][:10]}")
# Out:
# Vocabulary size: 10000
# Train: 4000 | Val: 1000
#
# Review : Forget what I said about Emeril. Rachael Ray is the most irritating personality ...
# Tokens : ['forget', 'what', 'i', 'said', 'about', 'emeril.', 'rachael', 'ray', 'is', 'the']
# Encoded: [896, 48, 9, 347, 42, 1, 1, 1528, 7, 2]

# %% [markdown]
# ### Task 1 — Implement Scaled Dot-Product Attention from Scratch
#
# Before using PyTorch's built-in attention, build your own.
#
# 1. Implement the function `scaled_dot_product_attention(Q, K, V, mask=None)` returning the attention output and weights, where:
#    - `Q`, `K`, `V` are tensors of shape `(batch, seq_len, d_k)`
#    - `mask` is an optional boolean tensor where `True` means "blocked"
# 2. Use it on a tiny example: 2 sequences of 4 tokens with `d_k=8`, all values random.
# 3. Verify your implementation matches `nn.functional.scaled_dot_product_attention` (or do a manual check that softmax rows sum to 1 and outputs match `weights @ V`).
# 4. Print the attention weight matrix for one example. In a markdown cell, comment on its shape and what each row represents.

# %%
import torch
import torch.nn.functional as F

# ── Attention function ────────────────────────────────────────
def scaled_dot_product_attention(Q, K, V, mask=None):
    d_k = Q.shape[-1]
    
    # 1. Calculate scores
    scores = Q @ K.transpose(-2, -1) / (d_k ** 0.5)
    
    # 2. Apply mask if present (set True positions to -inf)
    if mask is not None:
        scores = scores.masked_fill(mask, float('-inf'))
    
    # 3. Softmax → attention weights
    weights = F.softmax(scores, dim=-1)
    
    # 4. Weighted sum
    output = weights @ V
    
    return output, weights


# ── Test: 2 sequences, 4 tokens, d_k=8 ───────────────────────
torch.manual_seed(42)
batch, seq_len, d_k = 2, 4, 8

Q = torch.randn(batch, seq_len, d_k)
K = torch.randn(batch, seq_len, d_k)
V = torch.randn(batch, seq_len, d_k)

output, weights = scaled_dot_product_attention(Q, K, V)

print("Output shape :", output.shape)   # (2, 4, 8)
print("Weights shape:", weights.shape)  # (2, 4, 4)


# ── Verification: does each row sum up to 1? ──────────────────
print("\nSum of each row (should be 1):")
print(weights[0].sum(dim=-1))


# ── Comparison with PyTorch ───────────────────────────────────
pt_output = F.scaled_dot_product_attention(Q, K, V)
print("\nDifference with PyTorch:", (output - pt_output).abs().max().item())
# Should be 0.0 or a very small number


# ── Display attention weight matrix ──────────────────────────
print("\nAttention weights (1st sequence):")
print(weights[0].detach().numpy().round(3))
# Out:
# Output shape : torch.Size([2, 4, 8])
# Weights shape: torch.Size([2, 4, 4])
#
# Sum of each row (should be 1):
# tensor([1.0000, 1.0000, 1.0000, 1.0000])
#
# Difference with PyTorch: 3.5762786865234375e-07
#
# Attention weights (1st sequence):
# [[0.509 0.316 0.111 0.063]
#  [0.262 0.383 0.177 0.178]
#  [0.244 0.024 0.201 0.53 ]
#  [0.745 0.108 0.035 0.112]]

# %% [markdown]
# ## Attention Weight Matrix — Shape and Row Interpretation
#
# **Shape:** `(batch=2, seq_len=4, seq_len=4)`
#
# The weight matrix has shape `(2, 4, 4)`:
# - First dimension (`2`): batch size — two independent sequences
# - Second dimension (`4`): each of the 4 tokens acts as a **query**
# - Third dimension (`4`): scores assigned to each of the 4 tokens as **keys**
#
# **Each row** represents one query token's attention distribution
# over all tokens in the sequence (including itself).
# Since softmax is applied, every row sums to 1.0 —
# it is a probability distribution over positions.
#
# For example:
# - **Row 0 (T0):** weight 0.509 on itself → T0 focuses mostly on itself
# - **Row 2 (T2):** weight 0.530 on T3 → T2 attends most strongly to T3
# - **Row 3 (T3):** weight 0.745 on T0 → T3 draws heavily from T0's information
#
# In a real model these tokens would be words, and high attention weights
# would indicate meaningful relationships (e.g. a pronoun attending to its noun).
# Here Q, K, V are random, so the weights carry no linguistic meaning —
# this test only verifies that the mechanism works correctly./

# %% [markdown]
# ### Task 2 — LSTM Classifier
#
# 1. Define an `LSTMClassifier`:
#    - `nn.Embedding(vocab_size, embed_dim=64)`
#    - `nn.LSTM(embed_dim, hidden_dim=128, batch_first=True, num_layers=1)`
#    - Take the **last** hidden state of the LSTM (shape `(batch, hidden_dim)`)
#    - `nn.Dropout(0.3)` → `nn.Linear(hidden_dim, 2)` for binary classification
# 2. Train for **5 epochs** with `Adam(lr=1e-3)` and `CrossEntropyLoss`. Time the training with `time.time()`.
# 3. Plot training and validation loss + accuracy. Report best validation accuracy and total training time.

# %%
import time

# ── 1. Model ──────────────────────────────────────────────────
class LSTMClassifier(nn.Module):
    def __init__(self, vocab_size, embed_dim=64, hidden_dim=128, num_classes=2):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, embed_dim, padding_idx=0)
        self.lstm      = nn.LSTM(embed_dim, hidden_dim, batch_first=True, num_layers=1)
        self.dropout   = nn.Dropout(0.3)
        self.fc        = nn.Linear(hidden_dim, num_classes)

    def forward(self, x):
        embedded = self.embedding(x)               # (batch, seq_len, 64)
        _, (hidden, _) = self.lstm(embedded)       # hidden: (1, batch, 128)
        hidden = hidden.squeeze(0)                 # (batch, 128)
        out = self.dropout(hidden)
        return self.fc(out)                        # (batch, 2)


# ── 2. Train / Eval functions ─────────────────────────────────
def train_epoch(model, loader, optimizer, criterion):
    model.train()
    total_loss, correct = 0, 0
    for X, y in loader:
        X, y = X.to(device), y.to(device)
        optimizer.zero_grad()
        preds = model(X)
        loss  = criterion(preds, y)
        loss.backward()
        optimizer.step()
        total_loss += loss.item() * len(y)
        correct    += (preds.argmax(1) == y).sum().item()
    return total_loss / len(loader.dataset), correct / len(loader.dataset)


def eval_epoch(model, loader, criterion):
    model.eval()
    total_loss, correct = 0, 0
    with torch.no_grad():
        for X, y in loader:
            X, y = X.to(device), y.to(device)
            preds = model(X)
            loss  = criterion(preds, y)
            total_loss += loss.item() * len(y)
            correct    += (preds.argmax(1) == y).sum().item()
    return total_loss / len(loader.dataset), correct / len(loader.dataset)


# ── 3. Training loop ──────────────────────────────────────────
vocab_size = len(vocab)
model      = LSTMClassifier(vocab_size).to(device)
optimizer  = optim.Adam(model.parameters(), lr=1e-3)
criterion  = nn.CrossEntropyLoss()

history = {"train_loss": [], "val_loss": [], "train_acc": [], "val_acc": []}

start_time = time.time()

for epoch in range(1, 6):
    tr_loss, tr_acc = train_epoch(model, train_loader, optimizer, criterion)
    vl_loss, vl_acc = eval_epoch(model, val_loader, criterion)

    history["train_loss"].append(tr_loss)
    history["val_loss"].append(vl_loss)
    history["train_acc"].append(tr_acc)
    history["val_acc"].append(vl_acc)

    print(f"Epoch {epoch} | "
          f"Train Loss: {tr_loss:.4f}  Acc: {tr_acc:.4f} | "
          f"Val Loss: {vl_loss:.4f}  Acc: {vl_acc:.4f}")

total_time = time.time() - start_time
best_val_acc = max(history["val_acc"])

print(f"\nBest Val Accuracy : {best_val_acc:.4f}")
print(f"Total Training Time: {total_time:.1f}s")


# ── 4. Plot ───────────────────────────────────────────────────
epochs = range(1, 6)
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

ax1.plot(epochs, history["train_loss"], label="Train Loss")
ax1.plot(epochs, history["val_loss"],   label="Val Loss")
ax1.set_title("Loss")
ax1.set_xlabel("Epoch")
ax1.legend()

ax2.plot(epochs, history["train_acc"], label="Train Acc")
ax2.plot(epochs, history["val_acc"],   label="Val Acc")
ax2.set_title("Accuracy")
ax2.set_xlabel("Epoch")
ax2.legend()

plt.tight_layout()
plt.show()
# Out:
# Epoch 1 | Train Loss: 0.6942  Acc: 0.5060 | Val Loss: 0.6921  Acc: 0.5090
# Epoch 2 | Train Loss: 0.6826  Acc: 0.5433 | Val Loss: 0.6898  Acc: 0.5200
# Epoch 3 | Train Loss: 0.6622  Acc: 0.5745 | Val Loss: 0.7061  Acc: 0.5060
# Epoch 4 | Train Loss: 0.6312  Acc: 0.5903 | Val Loss: 0.7123  Acc: 0.5390
# Epoch 5 | Train Loss: 0.5731  Acc: 0.6478 | Val Loss: 0.7772  Acc: 0.5480
#
# Best Val Accuracy : 0.5480
# Total Training Time: 3.5s

# %% [markdown]
# ## Task 2 — LSTM Classifier Results
#
# ### Model Architecture
# - `nn.Embedding(vocab_size, embed_dim=64)`
# - `nn.LSTM(embed_dim=64, hidden_dim=128, batch_first=True, num_layers=1)`
# - Last hidden state → `nn.Dropout(0.3)` → `nn.Linear(128, 2)`
#
# ### Training Results
#
# | Epoch | Train Loss | Train Acc | Val Loss | Val Acc |
# |-------|-----------|-----------|----------|---------|
# | 1     | 0.6942    | 0.5060    | 0.6921   | 0.5090  |
# | 2     | 0.6826    | 0.5433    | 0.6898   | 0.5200  |
# | 3     | 0.6622    | 0.5745    | 0.7061   | 0.5060  |
# | 4     | 0.6312    | 0.5903    | 0.7123   | 0.5390  |
# | 5     | 0.5731    | 0.6478    | 0.7772   | 0.5480  |
#
# ### Summary
# - **Best Validation Accuracy:** 0.5480
# - **Total Training Time:** 3.5s
#
# ### Observations
# - Train loss steadily decreases while validation loss increases — a clear sign of **overfitting**
# - Validation accuracy barely exceeds 0.50 (random baseline), indicating the model struggles to generalise
# - The likely cause is the small dataset size (5000 samples, 4000 for training), which is insufficient for an LSTM to learn meaningful patterns

# %% [markdown]
# ### Task 3 — Transformer Classifier and Comparison with the LSTM
#
# Build a transformer encoder for the same sentiment task and compare it head-to-head against the LSTM you trained in Task 2.
#
# 1. Define a `TransformerClassifier`:
#    - `nn.Embedding(vocab_size, d_model=64)`
#    - A learned positional encoding `nn.Embedding(max_len=200, d_model=64)`
#    - `nn.TransformerEncoder` with `num_layers=2`, `d_model=64`, `nhead=4`, `dim_feedforward=128`, `batch_first=True`, `dropout=0.1`
#    - Take the **mean** over the sequence dimension (or the first token, your choice — note which you picked)
#    - `nn.Dropout(0.3)` → `nn.Linear(d_model, 2)`
# 2. Train for the same **5 epochs** with the same optimiser and loss. Time the training.
# 3. Plot training and validation loss + accuracy, report best validation accuracy and total training time, then fill in the comparison table below and write a **4–6 sentence comparison** of the two models — which converged faster per epoch, which ended at higher accuracy, and whether the transformer's parallelism noticeably affected training time on your hardware.
#
# | Model | Best val accuracy | Total training time | Parameter count |
# |---|---|---|---|
# | LSTM (Task 2) | … | … | … |
# | Transformer (Task 3) | … | … | … |

# %%
import time

# ── 1. Model ──────────────────────────────────────────────────
class TransformerClassifier(nn.Module):
    def __init__(self, vocab_size, d_model=64, nhead=4,
                 num_layers=2, dim_feedforward=128,
                 max_len=200, num_classes=2, dropout=0.1):
        super().__init__()
        self.word_emb = nn.Embedding(vocab_size, d_model, padding_idx=0)
        self.pos_emb  = nn.Embedding(max_len, d_model)

        encoder_layer = nn.TransformerEncoderLayer(
            d_model=d_model,
            nhead=nhead,
            dim_feedforward=dim_feedforward,
            dropout=dropout,
            batch_first=True
        )
        self.encoder  = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)
        self.dropout  = nn.Dropout(0.3)
        self.fc       = nn.Linear(d_model, num_classes)

    def forward(self, x):
        positions = torch.arange(x.size(1), device=x.device).unsqueeze(0)  # (1, seq_len)
        out = self.word_emb(x) + self.pos_emb(positions)                   # (batch, seq_len, 64)
        out = self.encoder(out)                                             # (batch, seq_len, 64)
        out = out.mean(dim=1)                                               # mean pooling → (batch, 64)
        out = self.dropout(out)
        return self.fc(out)                                                 # (batch, 2)


# ── 2. Parameter count helper ─────────────────────────────────
def count_params(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)


# ── 3. Training ───────────────────────────────────────────────
tf_model   = TransformerClassifier(vocab_size=len(vocab)).to(device)
optimizer  = optim.Adam(tf_model.parameters(), lr=1e-3)
criterion  = nn.CrossEntropyLoss()

tf_history = {"train_loss": [], "val_loss": [], "train_acc": [], "val_acc": []}

start_time = time.time()

for epoch in range(1, 6):
    tr_loss, tr_acc = train_epoch(tf_model, train_loader, optimizer, criterion)
    vl_loss, vl_acc = eval_epoch(tf_model, val_loader, criterion)

    tf_history["train_loss"].append(tr_loss)
    tf_history["val_loss"].append(vl_loss)
    tf_history["train_acc"].append(tr_acc)
    tf_history["val_acc"].append(vl_acc)

    print(f"Epoch {epoch} | "
          f"Train Loss: {tr_loss:.4f}  Acc: {tr_acc:.4f} | "
          f"Val Loss: {vl_loss:.4f}  Acc: {vl_acc:.4f}")

tf_total_time = time.time() - start_time
tf_best_val   = max(tf_history["val_acc"])

print(f"\nBest Val Accuracy : {tf_best_val:.4f}")
print(f"Total Training Time: {tf_total_time:.1f}s")
print(f"Parameter count    : {count_params(tf_model):,}")

# LSTM param count da göstərək
print(f"LSTM param count   : {count_params(model):,}")


# ── 4. Plot ───────────────────────────────────────────────────
epochs = range(1, 6)
fig, axes = plt.subplots(2, 2, figsize=(13, 8))

# Loss
axes[0,0].plot(epochs, history["train_loss"],    label="LSTM Train")
axes[0,0].plot(epochs, history["val_loss"],      label="LSTM Val")
axes[0,0].set_title("LSTM — Loss")
axes[0,0].legend()

axes[0,1].plot(epochs, tf_history["train_loss"], label="TF Train")
axes[0,1].plot(epochs, tf_history["val_loss"],   label="TF Val")
axes[0,1].set_title("Transformer — Loss")
axes[0,1].legend()

# Accuracy
axes[1,0].plot(epochs, history["train_acc"],     label="LSTM Train")
axes[1,0].plot(epochs, history["val_acc"],       label="LSTM Val")
axes[1,0].set_title("LSTM — Accuracy")
axes[1,0].legend()

axes[1,1].plot(epochs, tf_history["train_acc"],  label="TF Train")
axes[1,1].plot(epochs, tf_history["val_acc"],    label="TF Val")
axes[1,1].set_title("Transformer — Accuracy")
axes[1,1].legend()

plt.tight_layout()
plt.show()
# Out:
# Epoch 1 | Train Loss: 0.6799  Acc: 0.5477 | Val Loss: 0.5973  Acc: 0.6900
# Epoch 2 | Train Loss: 0.5642  Acc: 0.7087 | Val Loss: 0.5673  Acc: 0.7060
# Epoch 3 | Train Loss: 0.4424  Acc: 0.7950 | Val Loss: 0.5384  Acc: 0.7440
# Epoch 4 | Train Loss: 0.3314  Acc: 0.8565 | Val Loss: 0.5382  Acc: 0.7720
# Epoch 5 | Train Loss: 0.2159  Acc: 0.9215 | Val Loss: 0.6076  Acc: 0.7700
#
# Best Val Accuracy : 0.7720
# Total Training Time: 9.8s
# Parameter count    : 719,874
# LSTM param count   : 739,586

# %%
# ── Parameter count ───────────────────────────────────────────
lstm_params = count_params(model)
tf_params   = count_params(tf_model)

lstm_best_val  = max(history["val_acc"])
lstm_time      = 3.5
tf_best_val    = max(tf_history["val_acc"])
tf_time        = 9.8

print(f"{'Model':<12} {'Best Val Acc':>14} {'Train Time':>12} {'Param Count':>13}")
print("-" * 55)
print(f"{'LSTM':<12} {lstm_best_val:>14.4f} {lstm_time:>11.1f}s {lstm_params:>13,}")
print(f"{'Transformer':<12} {tf_best_val:>14.4f} {tf_time:>11.1f}s {tf_params:>13,}")
# Out:
# Model          Best Val Acc   Train Time   Param Count
# -------------------------------------------------------
# LSTM                 0.5480         3.5s       739,586
# Transformer          0.7720         9.8s       719,874

# %% [markdown]
# ## Task 3 — Transformer vs LSTM Comparison
#
# | Model       | Best Val Accuracy | Total Training Time | Parameter Count |
# |-------------|:-----------------:|:-------------------:|:---------------:|
# | LSTM        |      0.5480       |        3.5s         |     739,586     |
# | Transformer |      0.7720       |        9.8s         |     719,874     |
#
# ### Comparison
#
# The Transformer significantly outperformed the LSTM, achieving a best validation
# accuracy of 0.772 compared to 0.548 for the LSTM — a gap of over 22 percentage
# points. The LSTM barely exceeded random baseline (0.50), suggesting it failed to
# capture meaningful patterns in the data within 5 epochs. The Transformer converged
# faster per epoch, already reaching ~0.70 val accuracy by epoch 1, while the LSTM
# remained near 0.51. In terms of training time, the Transformer took 9.8s versus
# 3.5s for the LSTM — roughly 3× slower, which reflects the heavier attention
# computation across all token pairs. Both models showed signs of overfitting, but
# it was more pronounced in the Transformer: train accuracy climbed to ~0.91 while
# val accuracy plateaued at 0.77, likely due to the small dataset size (4000 training
# samples) being insufficient to fully regularise a ~720K parameter model.
